# %% [markdown]
# ## ຄະນະ: ວິທະຍາສາດທຳມະຊາດ
# ## ສາຂາ: ວິທະຍາສາດຄອມພິວເຕີ(Computer Science)

# %% [markdown]
#  # Porject: Mask Detection

# %%
import cv2
import tensorflow
import keras
from PIL import Image

# %% [markdown]
# ອ່ານ File ທີ່ໃຊ້ໃນການຈັບໃບໜ້າ

# %%
face_cascade = 'haarcascade_frontalface_default.xml'

# %% [markdown]
# ທຳການເປີດກ້ອງທີ່ຕິດກັບຄວມພິວເຕີທີ່ເກັບໄວ້ໃນຕົວແປ webcam

# %%
webcam = cv2.VideoCapture(0)

# %% [markdown]
# ຄຳສັ່ງ read() ເປັນຄຳສັ່ງທີ່ໃຊ້ອ່ານພາບຈາກ webcam ແຕ່ຂໍ້ມູນທີ່ໄດ້ຈາກ webcam ແມ່ນຂໍ້ມູນປະເພດ BGR

# %%
success, image_bgr = webcam.read()

# %% [markdown]
# ການສົ່ງຂໍ້ມູນຮູບພາບ ຫຼາຍໆຮູບພາບຕິດຕໍ່ກັນ ພວກເຮົາຕ້ອງໃຊ້ while loop ເພື່ອສົ່ງຄຳສັ່ງຂອງພາບຈາກ webcam ເພື່ອສະແດງເປັນວິດີໂອ

# %%
while True:
    success, image_bgr = webcam.read()
    if success:
        
        image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
        
        face_classifier = cv2.CascadeClassifier(face_cascade)
        faces = face_classifier.detectMultiScale(image_bw)
        print(f'There are {len(faces)} faces found.')
        for face in faces:
            x, y, w, h = face
            cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0,255,0), 2)
        cv2.imshow("Face Detection", image_bgr)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
webcam.release()
cv2.destroyAllWindows()
# Out:
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 3 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 3 faces found.
# There are 3 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 3 faces found.
# There are 2 faces found.
# There are 3 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.

# %% [markdown]
# ສ້າງຂໍ້ມູບຂອງຄົນທີ່ໃສ່ Mask ແລະ ບໍ່ໃສ່ mask ເພື່ອນຳໄປ train model

# %%
count = 0
while True:
    success, image_bgr = webcam.read()
    if success:
        image_org = image_bgr.copy()
        image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
        
        face_classifier = cv2.CascadeClassifier(face_cascade)
        faces = face_classifier.detectMultiScale(image_bw)
        print(f'There are {len(faces)} faces found.')
        for face in faces:
            x, y, w, h = face
            cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0,255,0), 2)
            cv2.imwrite(f'mask/mask_{count}.jpg', image_org[y:y+h, x:x+w])
            count+=1
        cv2.imshow("Face Detection", image_bgr)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
webcam.release()
cv2.destroyAllWindows()
# Out:
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 0 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 0 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 0 faces found.
# There are 0 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 0 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 3 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 0 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.
# There are 1 faces found.
# There are 2 faces found.
# There are 1 faces found.

# %% [markdown]
# ### ສ້າງ Classification Model

# %% [markdown]
# Teachable Machine ທີ່ຈະຮັບຮູບພາບເພື່ອໃຫ້ Model ລະບຸພາບທີ່ຕ້ອງການໄດ້ ເພື່ອແບ່ງປະເພດພາບທີ່ເຫັນອອກເປັນປະເພດຕ່າງໆ ເຊັ່ນ:ຄົນໃສ່ mask ແລະ ຄົນບໍ່ໃສ່Mask
# ເຊິ່ງຈະແບ່ງຂໍ້ມູນອອກເປັນຈັກປະເພດກໍໄດ້ ເຊິ່ງເອີ້ນວ່າ Class ເຮົາຈະເອົານຳພາບຂອງແຕ່ລະClass ເຂົ້າໄປໃຫ້ Machine Learning ຮຽນຮູ້ ແລະ ດາວໂຫລດໂປຣແກຣມທີ່ Ture ສຳເລັດແລ້ວມາໃຊ້ງານສ່ອນໜື່ງຂອງໂຄດຂອງເຮົາ

# %% [markdown]
# ### ສ້າງ Model ດ້ອຍໂປຣແກຣມສຳເລັດຮູບ

# %% [markdown]
# https://teachablemachine.withgoogle.com/train/image

# %% [markdown]
# ### ຮູບແບບການ Train model

# %% [markdown]
# ![](M.jpg)

# %% [markdown]
# ### ທຳຄວາມເຂົ້າໃຈ Medel ເບື້ອງຕົ້ນ

# %%
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np

# Load the model
model = load_model('keras_model.h5')

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1.
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)
# Replace this with the path to your image
image = Image.open('mask_3.jpg')
#resize the image to a 224x224 with the same strategy as in TM2:
#resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.ANTIALIAS)
 
#turn the image into a numpy array
image_array = np.asarray(image)
# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1
# Load the image into the array
data[0] = normalized_image_array

# run the inference
prediction = model.predict(data)
print(prediction)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [[5.6668014e-05 9.9994338e-01]]

# %% [markdown]
# ### ນຳເອົາ Model ມາປະກອບກັບ webcam ແລະ Face Detection

# %% [markdown]
#  ຂໍ້ມູນທີ່ຈາກ webcam ເປັນຂໍ້ມູນປະເພດ object array ເຊີ່ງຈະຕ້ອງແປງເປັນ Image object ໃນຮູບແບບຂອງ object ທີ່ໄດ້ຈາກການເປີດໄຟສຈາກຮູບ ແລະ ຕ້ອງແປງສີຈາກສີ BGR ເປັນ RGB
#  ຫຼັງຈາກທີ່ເຮົາແປງຂໍ້ມູນຂອງ Webcame ແລະປັບໃຫ້ເຂົ້າກັບຂໍ້ມູນທີ່ໃຊ້ຮ່ວມກັບ Model ທີ່ Train ມາແລ້ວ ເຮົາຈະລວມຄຳສັ່ງເຂົ້າກັນ ແລະ ສະແດງຜົນເປັນ real-time

# %%
import cv2
import tensorflow
from keras.models import load_model
from PIL import Image, ImageOps
import numpy as np

webcam = cv2.VideoCapture(0)
face_cascade = 'haarcascade_frontalface_default.xml'
face_classifier = cv2.CascadeClassifier(face_cascade)
model = load_model('keras_model.h5')
size = (224, 224)
while True:
    success, image_bgr = webcam.read()
    if success:
        
        image_bw = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
        image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
        
        faces = face_classifier.detectMultiScale(image_bw)
        for face in faces:
            x, y, w, h = face
            cface_rgb = Image.fromarray(image_rgb[y:y+h,x:x+w])
        
            data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

            image = cface_rgb

            image = ImageOps.fit(image, size, Image.ANTIALIAS)

            image_array = np.asarray(image)

            normalized_image_array = (image_array.astype(np.float32) / 127.0) - 1

            data[0] = normalized_image_array

            prediction = model.predict(data)
            print(prediction)
            if prediction[0][0] < prediction[0][1]:
                cv2.putText(image_bgr, 'MASKED', (x, y-7), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0),2)
                cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0,255,0), 2)
            else:
                cv2.putText(image_bgr, 'NON_MASKED', (x, y-7), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255),2)
                cv2.rectangle(image_bgr, (x, y), (x+w, y+h), (0,0,255), 2)
        cv2.imshow("Mask Detection", image_bgr)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break
webcam.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# [[9.9980611e-01 1.9396777e-04]]
# [[9.9989915e-01 1.0079374e-04]]
# [[9.9979621e-01 2.0379429e-04]]
# [[9.9982917e-01 1.7080648e-04]]
# [[9.9979848e-01 2.0156843e-04]]
# [[9.9983311e-01 1.6686982e-04]]
# [[9.996933e-01 3.067062e-04]]
# [[9.9989212e-01 1.0784482e-04]]
# [[9.9987197e-01 1.2802759e-04]]
# [[9.9983633e-01 1.6364576e-04]]
# [[9.998010e-01 1.990324e-04]]
# [[9.9988258e-01 1.1745393e-04]]
# [[9.9983299e-01 1.6695641e-04]]
# [[9.9978477e-01 2.1529976e-04]]
# [[9.998355e-01 1.644954e-04]]
# [[9.9987805e-01 1.2193937e-04]]
# [[9.9991465e-01 8.5317202e-05]]
# [[9.9982554e-01 1.7443801e-04]]
# [[9.9987090e-01 1.2912133e-04]]
# [[9.9984121e-01 1.5878376e-04]]
# [[9.9979633e-01 2.0366142e-04]]
# [[9.9985480e-01 1.4516478e-04]]
# [[9.9978417e-01 2.1583866e-04]]
# [[9.9987388e-01 1.2612545e-04]]
# [[9.9973935e-01 2.6064055e-04]]
# [[9.9945194e-01 5.4803083e-04]]
# [[9.9987555e-01 1.2444351e-04]]
# [[9.9981004e-01 1.8994531e-04]]
# [[9.9981767e-01 1.8237341e-04]]
# [[9.997117e-01 2.882465e-04]]
# [[9.9985063e-01 1.4929289e-04]]
# [[0.3480766  0.65192336]]
# [[7.6791417e-04 9.9923205e-01]]
# [[0.00252397 0.99747604]]
# [[0.9981515  0.00184845]]
# [[0.0179539  0.98204607]]
# [[0.07956985 0.9204301 ]]
# [[0.01515002 0.98484993]]
# [[0.00222098 0.9977791 ]]
# [[0.01191744 0.9880825 ]]
# [[0.10401654 0.8959835 ]]
# [[0.02206419 0.9779358 ]]
# [[0.22614452 0.77385545]]
# [[0.17492329 0.82507676]]
# [[0.18516521 0.8148348 ]]
# [[0.12067491 0.87932503]]
# [[0.00430145 0.9956986 ]]
# [[0.00149376 0.99850625]]
# [[4.3262652e-04 9.9956733e-01]]
# [[0.00136922 0.9986307 ]]
# [[0.00173594 0.99826413]]
# [[6.9018744e-04 9.9930978e-01]]
# [[5.316820e-04 9.994684e-01]]
# [[8.834556e-04 9.991165e-01]]
# [[0.00184841 0.9981516 ]]
# [[9.3330984e-04 9.9906677e-01]]
# [[0.00116955 0.9988305 ]]
# [[0.0031941 0.9968059]]
# [[0.04921089 0.9507891 ]]
# [[0.9668504 0.0331496]]
# [[0.34918922 0.6508107 ]]
# [[0.28932792 0.710672  ]]
# [[0.00507051 0.99492955]]
# [[3.949275e-04 9.996051e-01]]
# [[2.640014e-04 9.997360e-01]]
# [[3.8366922e-04 9.9961627e-01]]
# [[3.2382895e-04 9.9967623e-01]]
# [[4.3380758e-04 9.9956614e-01]]
# [[3.863604e-04 9.996137e-01]]
# [[4.3399935e-04 9.9956602e-01]]
# [[8.785684e-04 9.991215e-01]]
# [[2.5188446e-04 9.9974817e-01]]
# [[1.7943197e-04 9.9982065e-01]]
# [[1.10219386e-04 9.99889731e-01]]
# [[6.0237542e-04 9.9939764e-01]]
# [[1.0195385e-04 9.9989808e-01]]
# [[1.2196391e-04 9.9987805e-01]]
# [[1.7904009e-04 9.9982101e-01]]
# [[1.3638091e-04 9.9986362e-01]]
# [[2.5481128e-04 9.9974519e-01]]
# [[2.4662336e-04 9.9975342e-01]]
# [[1.4250426e-04 9.9985743e-01]]
# [[4.752924e-04 9.995247e-01]]
# [[2.0910808e-04 9.9979097e-01]]
# [[1.1235242e-04 9.9988759e-01]]
# [[2.9725366e-04 9.9970275e-01]]
# [[1.6922201e-04 9.9983072e-01]]
# [[2.3278358e-04 9.9976724e-01]]
# [[1.5907457e-04 9.9984086e-01]]
# [[8.553797e-05 9.999144e-01]]
# [[3.4979341e-04 9.9965024e-01]]
# [[4.2996567e-04 9.9957007e-01]]
# [[1.3391429e-04 9.9986601e-01]]
# [[1.5543286e-04 9.9984455e-01]]
# [[2.6632828e-04 9.9973363e-01]]
# [[2.8731333e-04 9.9971265e-01]]
# [[2.6635316e-04 9.9973363e-01]]
# [[3.8308339e-04 9.9961686e-01]]
# [[2.976521e-04 9.997023e-01]]
# [[4.8761445e-04 9.9951243e-01]]
# [[3.5133326e-04 9.9964869e-01]]
# [[4.5779551e-04 9.9954224e-01]]
# [[3.141033e-04 9.996859e-01]]
# [[2.4513892e-04 9.9975485e-01]]
# [[2.3334734e-04 9.9976665e-01]]
# [[0.00110315 0.99889684]]
# [[0.00258044 0.9974196 ]]
# [[9.3221938e-04 9.9906784e-01]]
# [[0.0017977 0.9982023]]
# [[0.001003   0.99899703]]
# [[9.3286525e-04 9.9906713e-01]]
# [[9.4635098e-04 9.9905366e-01]]
# [[9.9987173e-01 1.2830918e-04]]
# [[9.9982738e-01 1.7261665e-04]]
# [[9.998727e-01 1.272529e-04]]
# [[9.9981123e-01 1.8882142e-04]]
# [[0.9944284  0.00557164]]
# [[9.9982685e-01 1.7316033e-04]]
# [[9.9981290e-01 1.8712803e-04]]
# [[9.9991810e-01 8.1903934e-05]]
# [[9.9989235e-01 1.0758279e-04]]
# [[9.9985480e-01 1.4516976e-04]]
# [[9.9980277e-01 1.9721981e-04]]
# [[9.9985337e-01 1.4662746e-04]]
# [[9.9991846e-01 8.1586993e-05]]
# [[9.9983144e-01 1.6847915e-04]]
# [[9.9987054e-01 1.2944023e-04]]
# [[9.999075e-01 9.250119e-05]]
# [[9.9989140e-01 1.0860323e-04]]
# [[9.9991024e-01 8.9715344e-05]]
# [[9.9993396e-01 6.6011846e-05]]
# [[9.999050e-01 9.505031e-05]]
# [[9.9989939e-01 1.0054683e-04]]
# [[9.9969447e-01 3.0552104e-04]]
# [[9.9969792e-01 3.0214095e-04]]
# [[9.9973911e-01 2.6084363e-04]]
# [[9.999113e-01 8.863598e-05]]
# [[9.9984229e-01 1.5765798e-04]]
# [[0.985226   0.01477403]]
# [[0.00191059 0.9980894 ]]
# [[8.397943e-04 9.991602e-01]]
# [[0.0261996 0.9738004]]
# [[0.02269032 0.9773097 ]]
# [[0.0013962  0.99860376]]
# [[6.1532937e-04 9.9938464e-01]]
# [[8.0128340e-04 9.9919873e-01]]
# [[2.5031035e-04 9.9974972e-01]]
# [[7.749419e-04 9.992250e-01]]
# [[6.5280369e-04 9.9934715e-01]]
# [[0.01468139 0.98531866]]
# [[0.00468156 0.9953185 ]]
# [[0.02099645 0.9790036 ]]
# [[0.099658 0.900342]]
# [[0.05897161 0.9410285 ]]
# [[0.00776694 0.99223304]]
# [[0.00158438 0.9984156 ]]
# [[9.778201e-04 9.990221e-01]]
# [[0.0013246 0.9986754]]
# [[0.00160906 0.9983909 ]]
# [[0.00109603 0.998904  ]]
# [[5.2506558e-04 9.9947494e-01]]
# [[0.00198838 0.9980116 ]]
# [[0.00161602 0.998384  ]]
# [[0.00208464 0.9979153 ]]
# [[9.2788297e-04 9.9907207e-01]]
# [[0.00102878 0.9989712 ]]
# [[0.00157592 0.99842405]]
# [[3.2436906e-04 9.9967563e-01]]
# [[2.7129427e-04 9.9972874e-01]]
# [[5.5663480e-04 9.9944335e-01]]
# [[3.4953357e-04 9.9965048e-01]]
# [[7.202774e-04 9.992798e-01]]
# [[4.909614e-04 9.995090e-01]]
# [[3.7531616e-04 9.9962461e-01]]
# [[9.3472574e-04 9.9906534e-01]]
# [[6.970336e-04 9.993030e-01]]
# [[1.9859186e-04 9.9980146e-01]]
# [[6.353805e-04 9.993647e-01]]
# [[2.4725808e-04 9.9975270e-01]]
# [[0.00169002 0.99830997]]
# [[2.0143126e-04 9.9979860e-01]]
# [[6.118055e-04 9.993882e-01]]
# [[2.8075863e-04 9.9971920e-01]]
# [[5.0336024e-04 9.9949658e-01]]
# [[0.00159341 0.9984066 ]]
# [[0.02906082 0.9709392 ]]
# [[0.9370301  0.06296995]]
# [[0.87601686 0.1239831 ]]
# [[0.6416857  0.35831428]]
# [[0.01142681 0.9885732 ]]
# [[0.03554996 0.96445006]]
# [[0.0046842 0.9953158]]
# [[0.0049278 0.9950722]]
# [[0.00131936 0.99868065]]
# [[0.00163488 0.9983651 ]]
# [[8.2758337e-04 9.9917245e-01]]
# [[4.478387e-04 9.995522e-01]]
# [[0.00137844 0.9986216 ]]
# [[0.00118778 0.9988122 ]]
# [[0.00260354 0.99739647]]
# [[7.5560657e-04 9.9924445e-01]]
# [[7.9348596e-04 9.9920648e-01]]
# [[0.2979597 0.7020403]]
# [[9.9979061e-01 2.0945368e-04]]
# [[9.9982762e-01 1.7237964e-04]]
# [[9.9963200e-01 3.6796153e-04]]
# [[9.9990046e-01 9.9519217e-05]]
# [[9.999201e-01 7.988405e-05]]
# [[9.9985659e-01 1.4343907e-04]]
# [[9.9985564e-01 1.4430030e-04]]
# [[9.9975127e-01 2.4873854e-04]]
# [[9.999062e-01 9.377817e-05]]
# [[9.9960047e-01 3.9959865e-04]]
# [[9.9969113e-01 3.0885174e-04]]
# [[9.9965417e-01 3.4581913e-04]]
# [[9.9988401e-01 1.1598591e-04]]
# [[9.9978513e-01 2.1483896e-04]]
# [[9.995484e-01 4.515800e-04]]
# [[9.9956971e-01 4.3026987e-04]]
# [[9.9982458e-01 1.7547833e-04]]
# [[9.9982315e-01 1.7690111e-04]]
# [[0.99700755 0.00299246]]
# [[0.00592594 0.99407405]]
# [[0.00123946 0.9987606 ]]
# [[0.00141175 0.99858826]]
# [[0.00569611 0.9943039 ]]
# [[0.00131888 0.9986811 ]]
# [[6.944233e-04 9.993056e-01]]
# [[5.7935459e-04 9.9942064e-01]]
# [[3.2176799e-04 9.9967825e-01]]
# [[0.00101975 0.9989802 ]]
# [[0.00299313 0.99700683]]
# [[0.0204906 0.9795094]]
# [[0.00489964 0.9951003 ]]
# [[0.00146447 0.9985355 ]]
# [[0.00181579 0.99818414]]
# [[0.00246255 0.9975375 ]]
# [[0.0016277 0.9983724]]
# [[0.00229115 0.9977088 ]]
# [[0.0022053  0.99779475]]
